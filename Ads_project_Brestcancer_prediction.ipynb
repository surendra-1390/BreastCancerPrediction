# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
import pandas as pd

# %%
from sklearn.cluster import KMeans

from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier as dtc
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.feature_selection import mutual_info_classif

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import train_test_split


plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)

# %%
df = pd.read_csv("./breast-cancer.csv")

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 564  ...        25.450          26.40           166.10      2027.0
# 565  ...        23.690          38.25           155.00      1731.0
# 566  ...        18.980          34.12           126.70      1124.0
# 567  ...        25.740          39.42           184.60      1821.0
# 568  ...         9.456          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (569, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 142.4+ KB

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='diagnosis', data=df)

# %%
df = df.drop(columns=['id'])
CMAP='CMRmap'

# %%
df.describe().T.style.background_gradient(cmap='CMRmap')
# Out:
# <style type="text/css">
# #T_c6830_row0_col0, #T_c6830_row1_col0, #T_c6830_row2_col0, #T_c6830_row3_col0, #T_c6830_row4_col0, #T_c6830_row4_col1, #T_c6830_row4_col2, #T_c6830_row4_col3, #T_c6830_row4_col4, #T_c6830_row4_col5, #T_c6830_row4_col6, #T_c6830_row4_col7, #T_c6830_row5_col0, #T_c6830_row5_col1, #T_c6830_row5_col2, #T_c6830_row5_col3, #T_c6830_row5_col4, #T_c6830_row5_col5, #T_c6830_row5_col6, #T_c6830_row5_col7, #T_c6830_row6_col0, #T_c6830_row6_col1, #T_c6830_row6_col2, #T_c6830_row6_col3, #T_c6830_row6_col4, #T_c6830_row6_col5, #T_c6830_row6_col6, #T_c6830_row6_col7, #T_c6830_row7_col0, #T_c6830_row7_col1, #T_c6830_row7_col2, #T_c6830_row7_col3, #T_c6830_row7_col4, #T_c6830_row7_col5, #T_c6830_row7_col6, #T_c6830_row7_col7, #T_c6830_row8_col0, #T_c6830_row8_col1, #T_c6830_row8_col2, #T_c6830_row8_col3, #T_c6830_row8_col4, #T_c6830_row8_col5, #T_c6830_row8_col6, #T_c6830_row8_col7, #T_c6830_row9_col0, #T_c6830_row9_col1, #T_c6830_row9_col2, #T_c6830_row9_col3, #T_c6830_row9_col4, #T_c6830_row9_col5, #T_c6830_row9_col6, #T_c6830_row9_col7, #T_c6830_row10_col0, #T_c6830_row10_col1, #T_c6830_row10_col2, #T_c6830_row10_col3, #T_c6830_row10_col4, #T_c6830_row10_col5, #T_c6830_row10_col6, #T_c6830_row10_col7, #T_c6830_row11_col0, #T_c6830_row11_col1, #T_c6830_row11_col2, #T_c6830_row11_col3, #T_c6830_row11_col4, #T_c6830_row11_col5, #T_c6830_row11_col6, #T_c6830_row11_col7, #T_c6830_row12_col0, #T_c6830_row12_col1, #T_c6830_row12_col2, #T_c6830_row12_col4, #T_c6830_row12_col5, #T_c6830_row12_col6, #T_c6830_row13_col0, #T_c6830_row14_col0, #T_c6830_row14_col1, #T_c6830_row14_col2, #T_c6830_row14_col3, #T_c6830_row14_col4, #T_c6830_row14_col5, #T_c6830_row14_col6, #T_c6830_row14_col7, #T_c6830_row15_col0, #T_c6830_row15_col1, #T_c6830_row15_col2, #T_c6830_row15_col3, #T_c6830_row15_col4, #T_c6830_row15_col5, #T_c6830_row15_col6, #T_c6830_row15_col7, #T_c6830_row16_col0, #T_c6830_row16_col1, #T_c6830_row16_col2, #T_c6830_row16_col3, #T_c6830_row16_col4, #T_c6830_row16_col5, #T_c6830_row16_col6, #T_c6830_row16_col7, #T_c6830_row17_col0, #T_c6830_row17_col1, #T_c6830_row17_col2, #T_c6830_row17_col3, #T_c6830_row17_col4, #T_c6830_row17_col5, #T_c6830_row17_col6, #T_c6830_row17_col7, #T_c6830_row18_col0, #T_c6830_row18_col1, #T_c6830_row18_col2, #T_c6830_row18_col3, #T_c6830_row18_col4, #T_c6830_row18_col5, #T_c6830_row18_col6, #T_c6830_row18_col7, #T_c6830_row19_col0, #T_c6830_row19_col1, #T_c6830_row19_col2, #T_c6830_row19_col3, #T_c6830_row19_col4, #T_c6830_row19_col5, #T_c6830_row19_col6, #T_c6830_row19_col7, #T_c6830_row20_col0, #T_c6830_row21_col0, #T_c6830_row22_col0, #T_c6830_row23_col0, #T_c6830_row24_col0, #T_c6830_row24_col1, #T_c6830_row24_col2, #T_c6830_row24_col3, #T_c6830_row24_col4, #T_c6830_row24_col5, #T_c6830_row24_col6, #T_c6830_row24_col7, #T_c6830_row25_col0, #T_c6830_row25_col1, #T_c6830_row25_col2, #T_c6830_row25_col3, #T_c6830_row25_col4, #T_c6830_row25_col5, #T_c6830_row25_col6, #T_c6830_row25_col7, #T_c6830_row26_col0, #T_c6830_row26_col1, #T_c6830_row26_col2, #T_c6830_row26_col3, #T_c6830_row26_col4, #T_c6830_row26_col5, #T_c6830_row26_col6, #T_c6830_row26_col7, #T_c6830_row27_col0, #T_c6830_row27_col1, #T_c6830_row27_col2, #T_c6830_row27_col3, #T_c6830_row27_col4, #T_c6830_row27_col5, #T_c6830_row27_col6, #T_c6830_row27_col7, #T_c6830_row28_col0, #T_c6830_row28_col1, #T_c6830_row28_col2, #T_c6830_row28_col3, #T_c6830_row28_col4, #T_c6830_row28_col5, #T_c6830_row28_col6, #T_c6830_row28_col7, #T_c6830_row29_col0, #T_c6830_row29_col1, #T_c6830_row29_col2, #T_c6830_row29_col3, #T_c6830_row29_col4, #T_c6830_row29_col5, #T_c6830_row29_col6, #T_c6830_row29_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_c6830_row0_col1, #T_c6830_row0_col5, #T_c6830_row20_col1, #T_c6830_row20_col6 {
#   background-color: #050510;
#   color: #f1f1f1;
# }
# #T_c6830_row0_col2, #T_c6830_row0_col7, #T_c6830_row1_col2, #T_c6830_row12_col3, #T_c6830_row12_col7 {
#   background-color: #010104;
#   color: #f1f1f1;
# }
# #T_c6830_row0_col3, #T_c6830_row13_col3, #T_c6830_row13_col5, #T_c6830_row21_col5 {
#   background-color: #0b0b24;
#   color: #f1f1f1;
# }
# #T_c6830_row0_col4, #T_c6830_row1_col1, #T_c6830_row1_col6, #T_c6830_row20_col5 {
#   background-color: #060614;
#   color: #f1f1f1;
# }
# #T_c6830_row0_col6 {
#   background-color: #04040c;
#   color: #f1f1f1;
# }
# #T_c6830_row1_col3 {
#   background-color: #101034;
#   color: #f1f1f1;
# }
# #T_c6830_row1_col4, #T_c6830_row13_col4 {
#   background-color: #0a0a20;
#   color: #f1f1f1;
# }
# #T_c6830_row1_col5, #T_c6830_row21_col1, #T_c6830_row21_col6 {
#   background-color: #08081c;
#   color: #f1f1f1;
# }
# #T_c6830_row1_col7, #T_c6830_row20_col2, #T_c6830_row20_col7, #T_c6830_row21_col2, #T_c6830_row21_col7 {
#   background-color: #020208;
#   color: #f1f1f1;
# }
# #T_c6830_row2_col1 {
#   background-color: #1f1f68;
#   color: #f1f1f1;
# }
# #T_c6830_row2_col2, #T_c6830_row13_col6, #T_c6830_row20_col3, #T_c6830_row21_col4 {
#   background-color: #0c0c28;
#   color: #f1f1f1;
# }
# #T_c6830_row2_col3 {
#   background-color: #4826b8;
#   color: #f1f1f1;
# }
# #T_c6830_row2_col4 {
#   background-color: #2c268a;
#   color: #f1f1f1;
# }
# #T_c6830_row2_col5, #T_c6830_row13_col7 {
#   background-color: #262680;
#   color: #f1f1f1;
# }
# #T_c6830_row2_col6 {
#   background-color: #1d1d60;
#   color: #f1f1f1;
# }
# #T_c6830_row2_col7, #T_c6830_row13_col1 {
#   background-color: #0d0d2c;
#   color: #f1f1f1;
# }
# #T_c6830_row3_col1 {
#   background-color: #e6bd18;
#   color: #000000;
# }
# #T_c6830_row3_col2 {
#   background-color: #e77d02;
#   color: #f1f1f1;
# }
# #T_c6830_row3_col3 {
#   background-color: #e6c72f;
#   color: #000000;
# }
# #T_c6830_row3_col4 {
#   background-color: #e6d34f;
#   color: #000000;
# }
# #T_c6830_row3_col5 {
#   background-color: #e6d046;
#   color: #000000;
# }
# #T_c6830_row3_col6 {
#   background-color: #e6b114;
#   color: #000000;
# }
# #T_c6830_row3_col7 {
#   background-color: #ed6d0b;
#   color: #f1f1f1;
# }
# #T_c6830_row13_col2 {
#   background-color: #181850;
#   color: #f1f1f1;
# }
# #T_c6830_row20_col4 {
#   background-color: #070718;
#   color: #f1f1f1;
# }
# #T_c6830_row21_col3 {
#   background-color: #131340;
#   color: #f1f1f1;
# }
# #T_c6830_row22_col1 {
#   background-color: #25257c;
#   color: #f1f1f1;
# }
# #T_c6830_row22_col2, #T_c6830_row22_col7 {
#   background-color: #12123c;
#   color: #f1f1f1;
# }
# #T_c6830_row22_col3 {
#   background-color: #5928b5;
#   color: #f1f1f1;
# }
# #T_c6830_row22_col4 {
#   background-color: #312692;
#   color: #f1f1f1;
# }
# #T_c6830_row22_col5 {
#   background-color: #2b2688;
#   color: #f1f1f1;
# }
# #T_c6830_row22_col6 {
#   background-color: #232374;
#   color: #f1f1f1;
# }
# #T_c6830_row23_col1, #T_c6830_row23_col2, #T_c6830_row23_col3, #T_c6830_row23_col4, #T_c6830_row23_col5, #T_c6830_row23_col6, #T_c6830_row23_col7 {
#   background-color: #ffffff;
#   color: #000000;
# }
# </style>
# <table id="T_c6830_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6830_level0_row0" class="row_heading level0 row0" >radius_mean</th>
#       <td id="T_c6830_row0_col0" class="data row0 col0" >569.000000</td>
#       <td id="T_c6830_row0_col1" class="data row0 col1" >14.127292</td>
#       <td id="T_c6830_row0_col2" class="data row0 col2" >3.524049</td>
#       <td id="T_c6830_row0_col3" class="data row0 col3" >6.981000</td>
#       <td id="T_c6830_row0_col4" class="data row0 col4" >11.700000</td>
#       <td id="T_c6830_row0_col5" class="data row0 col5" >13.370000</td>
#       <td id="T_c6830_row0_col6" class="data row0 col6" >15.780000</td>
#       <td id="T_c6830_row0_col7" class="data row0 col7" >28.110000</td>
#     </tr>
#     <tr>
#       <th id="T_c6830_level0_row1" class="row_heading level0 row1"

# %%
#check missing value
df.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
df['diagnosis'] = df['diagnosis'].replace("M", 0)
df['diagnosis'] = df['diagnosis'].replace("B", 1)

# %%
#See Correlation Between Feature
df.corr().style.background_gradient(cmap = CMAP)
# Out:
# <style type="text/css">
# #T_c413d_row0_col0, #T_c413d_row1_col1, #T_c413d_row1_col3, #T_c413d_row2_col2, #T_c413d_row3_col1, #T_c413d_row3_col3, #T_c413d_row4_col4, #T_c413d_row5_col5, #T_c413d_row6_col6, #T_c413d_row7_col7, #T_c413d_row8_col8, #T_c413d_row9_col9, #T_c413d_row10_col10, #T_c413d_row11_col11, #T_c413d_row12_col12, #T_c413d_row13_col13, #T_c413d_row14_col14, #T_c413d_row15_col15, #T_c413d_row16_col16, #T_c413d_row17_col17, #T_c413d_row18_col18, #T_c413d_row19_col19, #T_c413d_row20_col20, #T_c413d_row21_col21, #T_c413d_row21_col23, #T_c413d_row22_col22, #T_c413d_row23_col21, #T_c413d_row23_col23, #T_c413d_row24_col24, #T_c413d_row25_col25, #T_c413d_row26_col26, #T_c413d_row27_col27, #T_c413d_row28_col28, #T_c413d_row29_col29, #T_c413d_row30_col30 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_c413d_row0_col1, #T_c413d_row0_col2, #T_c413d_row0_col3, #T_c413d_row0_col4, #T_c413d_row0_col5, #T_c413d_row0_col6, #T_c413d_row0_col7, #T_c413d_row0_col8, #T_c413d_row0_col9, #T_c413d_row0_col11, #T_c413d_row0_col13, #T_c413d_row0_col14, #T_c413d_row0_col16, #T_c413d_row0_col17, #T_c413d_row0_col18, #T_c413d_row0_col20, #T_c413d_row0_col21, #T_c413d_row0_col22, #T_c413d_row0_col23, #T_c413d_row0_col24, #T_c413d_row0_col25, #T_c413d_row0_col26, #T_c413d_row0_col27, #T_c413d_row0_col28, #T_c413d_row0_col29, #T_c413d_row0_col30, #T_c413d_row1_col10, #T_c413d_row21_col15, #T_c413d_row21_col19, #T_c413d_row28_col0, #T_c413d_row29_col12 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_c413d_row0_col10, #T_c413d_row1_col30, #T_c413d_row2_col5, #T_c413d_row4_col30, #T_c413d_row10_col4, #T_c413d_row14_col15 {
#   background-color: #4c26be;
#   color: #f1f1f1;
# }
# #T_c413d_row0_col12, #T_c413d_row0_col19 {
#   background-color: #242478;
#   color: #f1f1f1;
# }
# #T_c413d_row0_col15, #T_c413d_row10_col1, #T_c413d_row10_col2 {
#   background-color: #4926ba;
#   color: #f1f1f1;
# }
# #T_c413d_row1_col0, #T_c413d_row3_col10, #T_c413d_row3_col12, #T_c413d_row21_col20 {
#   background-color: #0b0b24;
#   color: #f1f1f1;
# }
# #T_c413d_row1_col2, #T_c413d_row2_col6, #T_c413d_row2_col14, #T_c413d_row3_col22, #T_c413d_row4_col2, #T_c413d_row5_col1, #T_c413d_row8_col30, #T_c413d_row15_col18 {
#   background-color: #fb4b20;
#   color: #f1f1f1;
# }
# #T_c413d_row1_col4, #T_c413d_row4_col1, #T_c413d_row4_col3 {
#   background-color: #fefefb;
#   color: #000000;
# }
# #T_c413d_row1_col5, #T_c413d_row13_col25, #T_c413d_row15_col9, #T_c413d_row17_col19, #T_c413d_row21_col9 {
#   background-color: #a43476;
#   color: #f1f1f1;
# }
# #T_c413d_row1_col6, #T_c413d_row16_col30, #T_c413d_row17_col28, #T_c413d_row18_col11, #T_c413d_row20_col6, #T_c413d_row20_col30, #T_c413d_row26_col3 {
#   background-color: #e6a10d;
#   color: #000000;
# }
# #T_c413d_row1_col7, #T_c413d_row13_col1, #T_c413d_row24_col7, #T_c413d_row30_col27 {
#   background-color: #e6d24c;
#   color: #000000;
# }
# #T_c413d_row1_col8, #T_c413d_row4_col8 {
#   background-color: #ebeb9b;
#   color: #000000;
# }
# #T_c413d_row1_col9, #T_c413d_row4_col9, #T_c413d_row10_col11, #T_c413d_row11_col29, #T_c413d_row12_col10, #T_c413d_row15_col27, #T_c413d_row19_col1, #T_c413d_row19_col24, #T_c413d_row20_col12, #T_c413d_row29_col17 {
#   background-color: #903287;
#   color: #f1f1f1;
# }
# #T_c413d_row1_col11, #T_c413d_row17_col27 {
#   background-color: #e6cd3f;
#   color: #000000;
# }
# #T_c413d_row1_col12, #T_c413d_row3_col0 {
#   background-color: #08081c;
#   color: #f1f1f1;
# }
# #T_c413d_row1_col13, #T_c413d_row8_col26 {
#   background-color: #e6cc3c;
#   color: #000000;
# }
# #T_c413d_row1_col14, #T_c413d_row4_col11, #T_c413d_row11_col8, #T_c413d_row13_col21 {
#   background-color: #e6d85c;
#   color: #000000;
# }
# #T_c413d_row1_col15, #T_c413d_row23_col0, #T_c413d_row28_col12 {
#   background-color: #010104;
#   color: #f1f1f1;
# }
# #T_c413d_row1_col16, #T_c413d_row3_col9, #T_c413d_row3_col17, #T_c413d_row4_col25, #T_c413d_row10_col13, #T_c413d_row14_col25, #T_c413d_row15_col28, #T_c413d_row21_col16, #T_c413d_row23_col17 {
#   background-color: #a13479;
#   color: #f1f1f1;
# }
# #T_c413d_row1_col17, #T_c413d_row12_col17, #T_c413d_row12_col27 {
#   background-color: #8e3189;
#   color: #f1f1f1;
# }
# #T_c413d_row1_col18, #T_c413d_row5_col21, #T_c413d_row9_col11, #T_c413d_row17_col3 {
#   background-color: #f35d15;
#   color: #f1f1f1;
# }
# #T_c413d_row1_col19, #T_c413d_row3_col15, #T_c413d_row4_col10, #T_c413d_row23_col12, #T_c413d_row23_col19 {
#   background-color: #060614;
#   color: #f1f1f1;
# }
# #T_c413d_row1_col20, #T_c413d_row24_col0, #T_c413d_row26_col12 {
#   background-color: #0a0a20;
#   color: #f1f1f1;
# }
# #T_c413d_row1_col21, #T_c413d_row3_col21, #T_c413d_row3_col23, #T_c413d_row11_col13, #T_c413d_row13_col11, #T_c413d_row21_col1, #T_c413d_row21_col3, #T_c413d_row23_col3 {
#   background-color: #fcfcef;
#   color: #000000;
# }
# #T_c413d_row1_col22, #T_c413d_row5_col4, #T_c413d_row7_col22, #T_c413d_row15_col25, #T_c413d_row19_col6, #T_c413d_row29_col1, #T_c413d_row30_col23 {
#   background-color: #fb4921;
#   color: #f1f1f1;
# }
# #T_c413d_row1_col23, #T_c413d_row4_col21, #T_c413d_row4_col23, #T_c413d_row21_col4, #T_c413d_row23_col1 {
#   background-color: #fbfbeb;
#   color: #000000;
# }
# #T_c413d_row1_col24, #T_c413d_row3_col24, #T_c413d_row24_col1, #T_c413d_row24_col3 {
#   background-color: #f9f9df;
#   color: #000000;
# }
# #T_c413d_row1_col25, #T_c413d_row9_col20, #T_c413d_row12_col23, #T_c413d_row17_col22, #T_c413d_row19_col3, #T_c413d_row19_col23, #T_c413d_row24_col9, #T_c413d_row24_col16 {
#   background-color: #9d347c;
#   color: #f1f1f1;
# }
# #T_c413d_row1_col26, #T_c413d_row14_col27, #T_c413d_row18_col4, #T_c413d_row28_col30, #T_c413d_row30_col5 {
#   background-color: #e68301;
#   color: #f1f1f1;
# }
# #T_c413d_row1_col27, #T_c413d_row5_col7, #T_c413d_row6_col24, #T_c413d_row13_col6, #T_c413d_row18_col13, #T_c413d_row28_col18, #T_c413d_row29_col27 {
#   background-color: #e6af13;
#   color: #000000;
# }
# #T_c413d_row1_col28, #T_c413d_row11_col24, #T_c413d_row24_col28, #T_c413d_row25_col5, #T_c413d_row26_col7, #T_c413d_row26_col30 {
#   background-color: #e6e172;
#   color: #000000;
# }
# #T_c413d_row1_col29, #T_c413d_row18_col2, #T_c413d_row19_col26, #T_c413d_row20_col24 {
#   background-color: #b43668;
#   color: #f1f1f1;
# }
# #T_c413d_row2_col0, #T_c413d_row14_col12 {
#   background-color: #4126ac;
#   color: #f1f1f1;
# }
# #T_c413d_row2_col1, #T_c413d_row2_col28, #T_c413d_row8_col16, #T_c413d_row10_col7, #T_c413d_row10_col9, #T_c413d_row10_col27 {
#   background-color: #e97705;
#   color: #f1f1f1;
# }
# #T_c413d_row2_col3, #T_c413d_row4_col26, #T_c413d_row8_col25, #T_c413d_row20_col26 {
#   background-color: #e77b03;
#   color: #f1f1f1;
# }
# #T_c413d_row2_col4, #T_c413d_row2_col8, #T_c413d_row9_col10, #T_c413d_row22_col8, #T_c413d_row26_col9, #T_c413d_row27_col11, #T_c413d_row27_col14 {
#   background-color: #ea7506;
#   color: #f1f1f1;
# }
# #T_c413d_row2_col7, #T_c413d_row13_col26, #T_c413d_row16_col11, #T_c413d_row19_col9, #T_c413d_row22_col7, #T_c413d_row26_col10, #T_c413d_row26_col17 {
#   background-color: #ed6d0b;
#   color: #f1f1f1;
# }
# #T_c413d_row2_col9, #T_c413d_row11_col12, #T_c413d_row17_col0, #T_c413d_row19_col30 {
#   background-color: #6c2ca5;
#   color: #f1f1f1;
# }
# #T_c413d_row2_col10 {
#   background-color: #36269a;
#   color: #f1f1f1;
# }
# #T_c413d_row2_col11, #T_c413d_row2_col13, #T_c413d_row16_col14, #T_c413d_row16_col24, #T_c413d_row17_col4, #T_c413d_row24_col2, #T_c413d_row26_col14 {
#   background-color: #f7531b;
#   color: #f1f1f1;
# }
# #T_c413d_row2_col12, #T_c413d_row12_col7, #T_c413d_row12_col18, #T_c413d_row15_col13, #T_c413d_row16_col25, #T_c413d_row18_col15, #T_c413d_row22_col25, #T_c413d_row30_col3 {
#   background-color: #da3b46;
#   color: #f1f1f1;
# }
# #T_c413d_row2_col15 {
#   background-color: #3b26a2;
#   color: #f1f1f1;
# }
# #T_c413d_row2_col16, #T_c413d_row9_col22, #T_c413d_row12_col3, #T_c413d_row12_col4, #T_c413d_row12_col24, #T_c413d_row12_col28, #T_c413d_row30_col2 {
#   background-color: #9a337e;
#   color: #f1f1f1;
# }
# #T_c413d_row2_col17, #T_c413d_row6_col19, #T_c413d_row15_col4, #T_c413d_row15_col23, #T_c413d_row15_col24, #T_c413d_row16_col12, #T_c413d_row18_col12, #T_c413d_row22_col9 {
#   background-color: #762d9d;
#   color: #f1

# %%
df['diagnosis'] = df['diagnosis'].replace(0, "M")
df['diagnosis'] = df['diagnosis'].replace(1, "B")

# %%
sns.relplot(x="area_mean", y="area_worst", hue='diagnosis', data=df)

# %%
sns.distplot(df['area_mean'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['area_worst'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.catplot(x='area_mean', kind='box', data=df)

# %%
sns.catplot(x='area_worst', kind='box', data=df)

# %% [markdown]
# #Data Preprocessing

# %%
#Check Duplicate
duplicate = df[df.duplicated()]
print("Duplicate Rows :")
duplicate
# Out:
# Duplicate Rows :
# Empty DataFrame
# Columns: [diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, fractal_dimension_mean, radius_se, texture_se, perimeter_se, area_se, smoothness_se, compactness_se, concavity_se, concave points_se, symmetry_se, fractal_dimension_se, radius_worst, texture_worst, perimeter_worst, area_worst, smoothness_worst, compactness_worst, concavity_worst, concave points_worst, symmetry_worst, fractal_dimension_worst]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # Data Manipulation

# %%
#scaler = MinMaxScaler(feature_range = (0 , 1))

X = df.drop('diagnosis', axis=1)
y = df['diagnosis']

# # Label encoding for categoricals
# for colname in X.select_dtypes("object"):
#     X[colname], _ = X[colname].factorize()

# list discrete features that have integer dtypes for using MI (Mutual Information)
discrete_features = X.dtypes == int

# %% [markdown]
# # Feature Selection

# %%
#use mutual information classify to select mutual feature
def make_mi_scores(X, y, discrete_features):
    mi_scores = mutual_info_classif(X, y, discrete_features=discrete_features)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

mi_scores = make_mi_scores(X, y, discrete_features)
mi_scores  # show a few features with their MI scores
# Out:
# perimeter_worst            0.476492
# area_worst                 0.464118
# radius_worst               0.453321
# concave points_mean        0.439054
# concave points_worst       0.438144
# perimeter_mean             0.403250
# concavity_mean             0.374912
# radius_mean                0.368837
# area_mean                  0.361553
# area_se                    0.340222
# concavity_worst            0.316013
# perimeter_se               0.273353
# radius_se                  0.247381
# compactness_worst          0.224889
# compactness_mean           0.213349
# concave points_se          0.128878
# texture_worst              0.125204
# concavity_se               0.117891
# smoothness_worst           0.098540
# symmetry_worst             0.097080
# texture_mean               0.094449
# smoothness_mean            0.083825
# compactness_se             0.073369
# fractal_dimension_worst    0.069027
# symmetry_mean              0.059884
# fractal_dimension_se       0.041314
# smoothness_se              0.016216
# symmetry_se                0.013426
# fractal_dimension_mean     0.004714
# texture_se                 0.004591
# Name: MI Scores, dtype: float64

# %%
def drop_uninformative(df, mi_scores):
    return df.loc[:, mi_scores > 0]

X = drop_uninformative(X, mi_scores)

# %%
X.columns
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# # Model Building
#
# 1.   List item
# 2.   List item

# %% [markdown]
# # 1.Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier as dtc

decision_tree = dtc(random_state=0)
decision_tree.fit(X,y)

predict = cross_val_predict(estimator = decision_tree, X = X, y = y, cv = 5)
print("Classification Report: \n",classification_report(y, predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            B       0.95      0.92      0.93       357
#            M       0.87      0.91      0.89       212
#
#     accuracy                           0.92       569
#    macro avg       0.91      0.92      0.91       569
# weighted avg       0.92      0.92      0.92       569

# %% [markdown]
# # 2.Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier(random_state = 0)
random_forest.fit(X, y)
predict = cross_val_predict(estimator = random_forest, X = X, y = y, cv = 5)
print("Classification Report: \n",classification_report(y, predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            B       0.97      0.98      0.97       357
#            M       0.96      0.94      0.95       212
#
#     accuracy                           0.96       569
#    macro avg       0.96      0.96      0.96       569
# weighted avg       0.96      0.96      0.96       569

# %% [markdown]
# # 3.KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(X,y)
predict = cross_val_predict(estimator = knn, X = X, y = y, cv = 5)
print("Classification Report: \n",classification_report(y, predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            B       0.93      0.96      0.94       357
#            M       0.93      0.87      0.90       212
#
#     accuracy                           0.93       569
#    macro avg       0.93      0.92      0.92       569
# weighted avg       0.93      0.93      0.93       569

# %% [markdown]
# # 4.SVC

# %%
from sklearn.svm import SVC

scv = SVC(degree=5,kernel="rbf",C=1.5)
scv.fit(X,y)
predict = cross_val_predict(estimator = scv, X = X, y = y, cv = 5)
print("Classification Report: \n",classification_report(y, predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            B       0.90      0.98      0.94       357
#            M       0.96      0.83      0.89       212
#
#     accuracy                           0.92       569
#    macro avg       0.93      0.90      0.91       569
# weighted avg       0.92      0.92      0.92       569

# %% [markdown]
# # 5.Gaussian Naive Base

# %%
gnb = GaussianNB()
gnb.fit(X,y)
predict = cross_val_predict(estimator = gnb, X = X, y = y, cv = 5)
print("Classification Report: \n",classification_report(y, predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            B       0.94      0.97      0.95       357
#            M       0.94      0.89      0.91       212
#
#     accuracy                           0.94       569
#    macro avg       0.94      0.93      0.93       569
# weighted avg       0.94      0.94      0.94       569

# %% [markdown]
# # 6.XGBoost

# %%
import xgboost as xgb

xgb_cl = xgb.XGBClassifier()

xgb_cl.fit(X,y)
predict = cross_val_predict(estimator = gnb, X = X, y = y, cv = 5)
print("Classification Report: \n",classification_report(y, predict))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            B       0.94      0.97      0.95       357
#            M       0.94      0.89      0.91       212
#
#     accuracy                           0.94       569
#    macro avg       0.94      0.93      0.93       569
# weighted avg       0.94      0.94      0.94       569
